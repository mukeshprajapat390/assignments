# %%
#1
l = [4,5,8,6,1,3]
l = list(set(l))
print(l)
# Out:
# [1, 3, 4, 5, 6, 8]

# %%
#2
t = (input(), input(), input(), input())
print(len(t))
print(max(t))
print(min(t))
print(sum(t))
# Out:
# 5
# 6
# 8
# 1
# 4
# 8
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-0af1271dd658> in <module>()
#       3 print(max(t))
#       4 print(min(t))
# ----> 5 print(sum(t))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#3
n = int(input('enter a no : '))
i = int(input('enter ith bit : '))
b = 1 << i
a = n | b
print(a)
# Out:
# enter a no : 13
# enter ith bit : 1
# 15

# %%
#4
n = int(input('enter a no : '))
m = n % 2
a = 1 if (m == 1) else 0
print(a)
# Out:
# enter a no : 7
# 1

# %%
#5
l1 = [ 1,5,9,7,6 ]
l2 = [ 5,4,3,1,7,]
print(l1)
print(l2)
a = l1 + l2
a = list(set(a))
print(a)
# Out:
# [1, 5, 9, 7, 6]
# [5, 4, 3, 1, 7]
# [1, 3, 4, 5, 6, 7, 9]
