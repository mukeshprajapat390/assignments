# %%
#ques1
l = [4,5,8,6,1,3]
l = list(set(l))
print(l)
# Out:
# [1, 3, 4, 5, 6, 8]

# %%
#ques2
lst = []
e = int(input('enter no of elements  : '))
for a in range(e):
    s = int(input('enter the numbers : '))
    lst.append(s)
t = tuple(lst)
print(t)
print(len(t))
print(max(t))
print(min(t))
print(sum(t))
# Out:
# enter no of elements  : 5
# enter the numbers : 4
# enter the numbers : 6
# enter the numbers : 9
# enter the numbers : 7
# enter the numbers : 2
# (4, 6, 9, 7, 2)
# 5
# 9
# 2
# 28

# %%
#ques3
n = int(input('enter a no : '))
i = int(input('enter ith bit : '))
b = 1 << i
a = n | b
print(a)
# Out:
# enter a no : 13
# enter ith bit : 1
# 15

# %%
#ques4
n = int(input('enter a no : '))
m = n % 2
a = 1 if (m == 1) else 0
print(a)
# Out:
# enter a no : 7
# 1

# %%
#ques5
a = [ 1,5,9,7,6 ]
b = [ 5,4,3,1,7,]
print(l1)
print(l2)
c = a + b
d = list(set(c))
print(d)
# Out:
# [1, 5, 9, 7, 6]
# [5, 4, 3, 1, 7]
# [1, 3, 4, 5, 6, 7, 9]

# %%
#ques6
n = int(input('enter the no of students : '))
students = {}
for a in range(n):
    student_name = input('name of students : ')
    student_marks = input('marks of students : ')
print(students)
